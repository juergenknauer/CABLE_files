# %%
# Write half-hourly GPP, Reco, NEP and ET OzFlux data to csv

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd
import netCDF4
import numpy as np
import re
import datetime
from matplotlib.backends.backend_pdf import PdfPages

# %%
##Sets up arrays used for loops
#Sites to loop through each location
#Sites = ['Tumbarumba','Warra','WombatStateForest','CumberlandPlain']
Sites = ['Tumbarumba']
Vars = ['GPP_SOLO', 'NEP_SOLO', 'ET', 'ER_SOLO']
csvVars = ['GPP', 'NEP', 'evap', 'Reco']

# %%
##sets up default info
#puts everything into an overarching dataframe
def Setup_Default(site, Everything, Vars):
##Sets up file info in nc
    print(site)
#    url='http://dap.ozflux.org.au/thredds/fileServer/ozflux/sites/' + site + '/L6/default/' + site + '_L6.nc'
    url='http://dap.ozflux.org.au/thredds/dodsC/ozflux/sites/' + site + '/L6/default/' + site + '_L6.nc'
    nc = netCDF4.Dataset(url,'r')
    nc.set_auto_mask(False)
    times = nc.variables['time']
    jd = netCDF4.num2date(times[:],times.units,)
##Loop over variable type 
    for x in range (0,len(Vars)):
##Try catches any that are found, except prevents stops
##saves into dataframe, remmoves outliers, resamples into monthly and annual dataframes
        Name = Vars[x]     
        QCFlagName = Name + '_QCFlag'
        print(Name,' ',QCFlagName)
        try:
            h = nc.variables[Name]
            Everything[Name] = pd.Series(h[:,0,0], index = jd)
            h = nc.variables[QCFlagName]
            Everything[QCFlagName] = pd.Series(h[:,0,0], index = jd)
            Everything.loc[Everything[QCFlagName] != 0, Name] = -9999.0  # replace data without QCFlag=0 with -9999
        except KeyError:
            Filler = 0

# %%
##exports info to csv
#one file for every processing type
def Export_to_csv(site, Vars, csvVars):
    Compiled = pd.DataFrame()
    Compiled_Plot = pd.DataFrame()
    fig=plt.figure(figsize=(10, 6.7))
    path = './'
    for y in range (0,len(csvVars)):
##Checks if it has data for each variable
        try:
            ##Sorts info for each file to Compiled dataframe
            Compiled[csvVars[y]] = Everything[Vars[y]]
        except KeyError:
            FillerNUM = 1      
#if no data is found for the site, doesn't create an empty csv
    if Compiled.empty:
        fillerNum = 1
##prints compiled data to csv
    else:
        Compiled['date'] = Compiled.index    
        if (site == 'WombatStateForest'):
            Compiled.loc[Compiled['date'] == datetime.datetime(2016,1,24,2,30),['GPP','NEP','Reco']] = -9999.0
        Compiled['Year'] = Compiled.date.dt.year
        Compiled['Month'] = Compiled.date.dt.month
        Compiled['Day'] = Compiled.date.dt.day
        Compiled['Hour'] = Compiled.date.dt.hour
        if (site != 'Tumbarumba'):
            Compiled['Minute'] = Compiled.date.dt.minute
        Compiled_Plot = Compiled.copy()    
        Compiled_Plot.replace(to_replace=-9999.0, value=np.NaN, inplace=True)
        for y in range (0,len(csvVars)):
            if not Compiled_Plot[csvVars[y]].isnull().all():
                print('plot ',csvVars[y])
                ax = plt.subplot2grid((4,1),(y, 0))    
                ax.plot(Compiled_Plot.date.dt.date,Compiled_Plot[csvVars[y]])
                ax.set_title(site+' '+csvVars[y]+' - zero flag',size=12.0) 
        plt.tight_layout()
        plt.show() 
        plotflnm = path + site + '_zeroflag.pdf'
        fig.savefig(plotflnm) #,dpi=fig.dpi, bbox_inches='tight')
        plt.close(fig)    
        #Compiled = Compiled.drop(columns = ['date'])
        del Compiled['date']
        if (site != 'Tumbarumba'):
            Compiled.set_index(['Year', 'Month', 'Day', 'Hour', 'Minute'], inplace = True)
        else:
            Compiled.set_index(['Year', 'Month', 'Day', 'Hour'], inplace = True)
        if (site == 'Tumbarumba'):
            tres = 'Hourly'
        else:
            tres = 'HalfHourly'
        flnm = path + site + '_' + tres + '.csv'
        print('writing to file ',flnm)
        Compiled.to_csv(flnm, sep=',', index = True)

# %%
for A in range (0, len(Sites)):
##Sets up dataframes
    Everything = pd.DataFrame() 
    Setup_Default(Sites[A], Everything, Vars)
    #print(Everything[:5])
    Export_to_csv(Sites[A], Vars, csvVars)
# Out:
# Tumbarumba
# GPP_SOLO   GPP_SOLO_QCFlag
# NEP_SOLO   NEP_SOLO_QCFlag
# ET   ET_QCFlag
# ER_SOLO   ER_SOLO_QCFlag
# plot  GPP
# plot  NEP
# plot  evap
# plot  Reco
# writing to file  ./Tumbarumba_Hourly.csv

# %%
site = 'Warra'
url='http://dap.ozflux.org.au/thredds/dodsC/ozflux/sites/' + site + '/L6/default/' + site + '_L6.nc'
nc = netCDF4.Dataset(url,'r')
nc.set_auto_mask(False)
nc
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     _NCProperties: version=1|netcdflibversion=4.4.1|hdf5libversion=1.8.17
#     BulkDensity: 950
#     EPDversion: 2.7.12 |Anaconda custom (64-bit)| (default, Jul  2 2016, 17:42:40)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
#     FgDepth: 0.08
#     Functions: ,do_linear, TaFromTv, CalculateMetVars, CoordRotation2D, CalculateFluxes, FhvtoFh, CorrectFgForStorage,RangeCheck,do_qcchecks, GapFillFromClimatology, GapFillFromalternate, GapFillUsingSOLO, ERUsingSOLO, ERUsingFFNET
#     OrganicContent: 0.045
#     QC_version: PyFluxPro V0.1.2
#     SwsDefault: 0.15
#     SwsSeries: ['Sws']
#     acknowledgement: This work used eddy covariance data collected by the TERN-OzFlux facility. OzFlux
# would like to acknowledge the financial support of the Australian Federal Government via
# the National Collaborative Research Infrastructure Scheme and the Education Investment
# Fund.
#     canopy_height: 55m
#     comment: CF metadata, OzFlux standard variable names
#     contact: Tim Wardlaw
#     controlfile_name: controlfiles/OzFlux/Tower/L6/Warra.txt
#     conventions: CF-1.6
#     conventions_names: CF convention standard names table version 27, 28 Nov 2013, audited 4 Jan 2015
#     coverage_flux_L3: 79
#     coverage_flux_L4: 79
#     coverage_flux_L5: 93
#     coverage_flux_L6: 93
#     coverage_meteorology_L3: 92
#     coverage_meteorology_L4: 100
#     coverage_meteorology_L5: 100
#     coverage_meteorology_L6: 100
#     coverage_radiation_L3: 99
#     coverage_radiation_L4: 100
#     coverage_radiation_L5: 100
#     coverage_radiation_L6: 100
#     coverage_soil_L3: 96
#     coverage_soil_L4: 100
#     coverage_soil_L5: 100
#     coverage_soil_L6: 100
#     data_url: http://data.ozflux.org.au/
#     doi: DOI:????
#     elevation:
#     end_date: 2017-04-24 10:00:00
#     featureType: timeseries
#     history:
#     institution: Forestry Tasmania
#     irga_type: EC155
#     latitude: -43.09502
#     license_type: TERN-BY-SA-NC
#     license_url: http://www.tern.org.au/datalicence/TERN-BY-SA-NC/1.0
#     longitude: 146.65452
#     metadata_url: http://http://www.ozflux.org.au/monitoringsites/Warra/index.html
#     nc_level: L6
#     nc_nrecs: 29129
#     nc_rundatetime: 2018-03-23 15:15:45
#     ozflux_url: http://ozflux.org.au/
#     references: None
#     site_name: Warra
#     site_pi: Tim Wardlaw
#     soil: Kurosolic Redoxic Hydrosol
#     source: McIntosh, P.D. (2012)
#     start_date: 2015-08-26 14:00:00
#     time_step: 30
#     time_zone: Australia/Hobart
#     title: Flux tower data set from the Warra site for the calendar year 2015
#     tower_height: 80
#     vegetation: Eucalyptus obliqua tall forest
#     xl_datemode: 0
#     xl_filename: ../Sites/Warra/Data/Processed/2015/Warra_2015_Feb_to_Dec_L1.xlsx
#     xl_moddatetime: 2016-10-12 09:44:14
#     Flag00: Good data
#     Flag01: QA/QC: Missing value in L1 dataset
#     Flag02: QA/QC: L2 Range Check
#     Flag03: QA/QC: CSAT Diagnostic
#     Flag04: QA/QC: LI7500 Diagnostic
#     Flag05: QA/QC: L2 Diurnal SD Check
#     Flag06: QA/QC: Excluded Dates
#     Flag07: QA/QC: Excluded Hours
#     Flag08: QA/QC: Missing value found with QC flag = 0
#     Flag10: Corrections: Apply Linear
#     Flag11: Corrections/Combinations: Coordinate Rotation (Ux, Uy, Uz, UxT, UyT, UzT, UxA, UyA, UzA, UxC, UyC, UzC, UxUz, UxUx, UxUy, UyUz, UxUy, UyUy)
#     Flag12: Corrections/Combinations: Massman Frequency Attenuation Correction (Coord Rotation, Tv_CSAT, Ah_HMP, ps)
#     Flag13: Corrections/Combinations: Virtual to Actual Fh (Coord Rotation, Massman, Ta_HMP)
#     Flag14: Corrections/Combinations: WPL correction for flux effects on density measurements (Coord Rotation, Massman, Fhv to Fh, Cc_7500_Av)
#     Flag15: Corrections/Combinations: Ta from Tv
#     Flag16: Corrections/Combinations: L3 Range Check
#     Flag17: Corrections/Combinations: L3 Diurnal SD Check
#     Flag18: Corrections/Combinations: u* filter
#     Flag19: Corrections/Combinations: Gap coordination
#     Flag20: GapFilling: Driver gap filled using ACCESS
#     Flag21: GapFilling: Used non-rotated covariance
#     Flag30: GapFilling: Flux gap filled by ANN (SOLO)
#     Flag31: GapFilling: Flux gap not filled by ANN
#     Flag38: GapFilling: L4 Range Check
#     Flag39: GapFilling: L4 Diurnal SD Check
#     Flag40: GapFilling: Gap filled by climatology
#     Flag50: GapFilling: Gap filled by interpolation
#     Flag60: GapFilling: Flux gap filled using ratios
#     dimensions(sizes): latitude(1), longitude(1), time(29129)
#     variables(dimensions): float64 time(time), float64 latitude(latitude), float64 longitude(longitude), int32 crs(), int32 Day(time,latitude,longitude), int32 Day_QCFlag(time,latitude,longitude), float64 Ddd(time,latitude,longitude), int32 Ddd_QCFlag(time,latitude,longitude), float64 Hdh(time,latitude,longitude), int32 Hdh_QCFlag(time,latitude,longitude), int32 Hour(time,latitude,longitude), int32 Hour_QCFlag(time,latitude,longitude), int32 Minute(time,latitude,longitude), int32 Minute_QCFlag(time,latitude,longitude), int32 Month(time,latitude,longitude), int32 Month_QCFlag(time,latitude,longitude), int32 Second(time,latitude,longitude), int32 Second_QCFlag(time,latitude,longitude), int32 Year(time,latitude,longitude), int32 Year_QCFlag(time,latitude,longitude), float64 xlDateTime(time,latitude,longitude), int32 xlDateTime_QCFlag(time,latitude,longitude), float64 Ah(time,latitude,longitude), int32 Ah_QCFlag(time,latitude,longitude), float64 Cc(time,latitude,longitude), int32 Cc_QCFlag(time,latitude,longitude), float64 E0_LL(time,latitude,longitude), int32 E0_LL_QCFlag(time,latitude,longitude), float64 ER(time,latitude,longitude), int32 ER_QCFlag(time,latitude,longitude), float64 ER_FFNET(time,latitude,longitude), int32 ER_FFNET_QCFlag(time,latitude,longitude), float64 ER_FFNET_all(time,latitude,longitude), int32 ER_FFNET_all_QCFlag(time,latitude,longitude), float64 ER_LL(time,latitude,longitude), int32 ER_LL_QCFlag(time,latitude,longitude), float64 ER_LL_all(time,latitude,longitude), int32 ER_LL_all_QCFlag(time,latitude,longitude), float64 ER_LT(time,latitude,longitude), int32 ER_LT_QCFlag(time,latitude,longitude), float64 ER_LT_all(time,latitude,longitude), int32 ER_LT_all_QCFlag(time,latitude,longitude), float64 ER_SOLO(time,latitude,longitude), int32 ER_SOLO_QCFlag(time,latitude,longitude), float64 ER_SOLO_all(time,latitude,longitude), int32 ER_SOLO_all_QCFlag(time,latitude,longitude), float64 ET(time,latitude,longitude), int32 ET_QCFlag(time,latitude,longitude), float64 ET_SOLO(time,latitude,longitude), int32 ET_SOLO_QCFlag(time,latitude,longitude), float64 Fa(time,latitude,longitude), int32 Fa_QCFlag(time,latitude,longitude), float64 Fc(time,latitude,longitude), int32 Fc_QCFlag(time,latitude,longitude), float64 Fc_SOLO(time,latitude,longitude), int32 Fc_SOLO_QCFlag(time,latitude,longitude), float64 Fc_filtered(time,latitude,longitude), int32 Fc_filtered_QCFlag(time,latitude,longitude), float64 Fc_nofilter(time,latitude,longitude), int32 Fc_nofilter_QCFlag(time,latitude,longitude), float64 Fc_storage(time,latitude,longitude), int32 Fc_storage_QCFlag(time,latitude,longitude), float64 Fe(time,latitude,longitude), int32 Fe_QCFlag(time,latitude,longitude), float64 Fe_SOLO(time,latitude,longitude), int32 Fe_SOLO_QCFlag(time,latitude,longitude), float64 Fg(time,latitude,longitude), int32 Fg_QCFlag(time,latitude,longitude), float64 Fh(time,latitude,longitude), int32 Fh_QCFlag(time,latitude,longitude), float64 Fh_SOLO(time,latitude,longitude), int32 Fh_SOLO_QCFlag(time,latitude,longitude), float64 Fld(time,latitude,longitude), int32 Fld_QCFlag(time,latitude,longitude), float64 Flu(time,latitude,longitude), int32 Flu_QCFlag(time,latitude,longitude), float64 Fm(time,latitude,longitude), int32 Fm_QCFlag(time,latitude,longitude), float64 Fn(time,latitude,longitude), int32 Fn_QCFlag(time,latitude,longitude), float64 Fsd(time,latitude,longitude), int32 Fsd_QCFlag(time,latitude,longitude), float64 Fsd_syn(time,latitude,longitude), int32 Fsd_syn_QCFlag(time,latitude,longitude), float64 Fsu(time,latitude,longitude), int32 Fsu_QCFlag(time,latitude,longitude), float64 GPP_FFNET(time,latitude,longitude), int32 GPP_FFNET_QCFlag(time,latitude,longitude), float64 GPP_LL(time,latitude,longitude), int32 GPP_LL_QCFlag(time,latitude,longitude), float64 GPP_LL_all(time,latitude,longitude), int32 GPP_LL_all_QCFlag(time,latitude,longitude), float64 GPP_LT(time,latitude,longitude), int32 GPP_LT_QCFlag(time,latitude,longitude), float64 GPP_SOLO(time,lat ...
#     groups:

# %%
print(nc.variables['ET'].units)
# Out:
# mm
